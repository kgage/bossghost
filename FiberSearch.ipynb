# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

import ghosts

# %% [markdown]
# flux2.dat contains all of the fibers from flux1.dat that ghosts.high_spikes accepts.

# %%
test = ghosts.high_spikes(ghosts.mirror.local_path('bossghost/flux2.dat'))

# %%
test
# Out:
# {'3953-55322-4': 1636.5166,
#  '4479-55592-56': 2325.8035,
#  '5297-55913-864': 1451.5529,
#  '5379-55986-602': 1633.0038,
#  '5467-55973-472': 1739.7664,
#  '5731-56363-616': 1671.0758,
#  '5769-56246-338': 1513.1482,
#  '6052-56092-752': 1087.9471,
#  '6115-56237-791': 1334.4436,
#  '6498-56565-347': 2418.4797,
#  '6829-56453-534': 1018.7943,
#  '6832-56426-126': 1556.6705,
#  '7101-56659-72': 4156.1899}

# %%
for key in test:
    s = key.split('-')
    g = ghosts.flux_data(int(s[0]),int(s[1]),int(s[2]))
    sp = g.main_spike()
    print(key)
    d =sp.distance()
    print('dist1 = {} \ndist2 = {}'.format(d[0],d[1]))
    sp.plt_floor()
# Out:
# 5769-56246-338
# dist1 = 0.177579096745
# dist2 = 0.117216571129
# 6829-56453-534
# dist1 = 0.226381993776
# dist2 = 0.313656572334
# 6498-56565-347
# dist1 = 0.046164098232
# dist2 = 0.0875315762168
# 6052-56092-752
# dist1 = 0.25454815578
# dist2 = 0.132607024699
# 5467-55973-472
# dist1 = 0.191266533895
# dist2 = 0.20816465347
# 6115-56237-791
# dist1 = 0.0381622709069
# dist2 = 0.1507002229
# 7101-56659-72
# dist1 = 0.108278411534
# dist2 = 0.389719744818
# 4479-55592-56
# dist1 = 0.394106034303
# dist2 = 0.27491078181
# 5731-56363-616
# dist1 = 0.183582688802
# dist2 = 0.126976585335
# 3953-55322-4
# dist1 = 0.360935557281
# dist2 = 0.381557713779
# 5297-55913-864
# dist1 = 0.0669590690364
# dist2 = 0.214571333891
# 6832-56426-126
# dist1 = 0.1384823478
# dist2 = 0.262108274706
# 5379-55986-602
# dist1 = 0.0723701404108
# dist2 = 0.147409451483
