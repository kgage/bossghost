# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

import ghosts

import time

# %% [markdown]
# Use fiber 4 from plate 3953 (mjd 55322) as it has the largest peak I have seen thus far.

# %%
data = ghosts.flux_data(3953,55322,4)

# %%
data.plt_all()

# %%
data.main_flux()
# Out:
# 1636.5166

# %%
data.plt_mid(wlen_range = [6500,7000])

# %%
spike1 = data.main_spike()
spike2 = data.main_spike(down = 20, up = 25)

# %%
spike1.plt_all(coeff = 3.5, sep = False, small = True)
spike2.plt_all(coeff = 3.5, sep = False, small = True)

# %%
spike1.plt_floor(coeff = 3.5)

# %%
spike1.integrate(coeff = 3.5, print_all = True)
spike2.integrate(coeff = 3.5, print_all = True)
# Out:
# Fiber 0003: 167.28
# Fiber 0004: 74.06
# Fiber 0005: 70.40
# Fiber 0003: 147.53
# Fiber 0004: 72.90
# Fiber 0005: 58.62
# (147.52879, 72.895599, 58.622524)

# %%
spike1.approx_coeff(3)
# Out:
# 7.9058652

# %%
spike1.approx_coeff(5)
# Out:
# 3.3270273
