# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

import ghosts

# %%
g1 = ghosts.flux_data(6498,56565,347)
g2 = ghosts.flux_data(5731,56363,616)
g3 = ghosts.flux_data(7101,56659,72)
g4 = ghosts.flux_data(3953,55322,4)

# %%
s1_1 = g1.main_spike(up = 24, down = 55)
s1_1.plt_all(small = True)

# %%
s1_1.plt_floor(save = '6498-56565-347.png')
s1_1.integrate()
# Out:
# Fiber 0346: 11.15
# Fiber 0347: 34.98
# Fiber 0348: 18.27

# %%
s1_2=g1.main_spike(up = 20)
s1_2.plt_floor()
s1_2.integrate()
# Out:
# Fiber 0346: 46.77
# Fiber 0347: 31.83
# Fiber 0348: 30.89

# %%
s2 = g2.main_spike(down = 29)
s2.plt_floor(save = '5731-56363-616.png')
s2.integrate()
# Out:
# Fiber 0615: 22.38
# Fiber 0616: 16.32
# Fiber 0617: 20.61

# %%
0.3*(6673-6578)-18.57
# Out:
# 9.93

# %%
s3 = g3.main_spike(down = 20)
s3.plt_floor(save = '7101-56659-72.png')
s3.integrate()
# Out:
# Fiber 0071: 47.41
# Fiber 0072: 25.26
# Fiber 0073: 21.54

# %%
s4 = g4.main_spike()
s4.plt_floor(save = '3953-55322-4.png')
s4.integrate()
# Out:
# Fiber 0003: 172.76
# Fiber 0004: 21.22
# Fiber 0005: 85.58
